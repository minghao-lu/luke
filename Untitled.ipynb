# %%
print ("hellow world")
# Out:
# hellow world

# %%
a=1
print a
# Out:
#   Cell In[2], line 2
#     print a
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
10+3
# Out:
# 13

# %% [markdown]
# there is anexample markdown.here is anexample math $x=3+y$

# %%
import pandas as pd

# Load the dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# Get missing data counts
missing_counts = df.isnull().sum()
missing_counts
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
